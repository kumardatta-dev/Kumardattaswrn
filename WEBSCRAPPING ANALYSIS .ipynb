# %%
import numpy as np
import pandas as pd
import requests

# %%
DF=pd.read_csv("REFRIGERATORS_FINAL_DATASET")

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RATING       367 non-null    float64
#  1   PRICESS      432 non-null    float64
#  2   COOLING SYS  430 non-null    object
#  3   BRAND STAR   432 non-null    int64
#  4   STABILIZER   345 non-null    object
#  5   Brand        432 non-null    object
#  6   INVERTER     432 non-null    object
#  7   LITERS       432 non-null    float64
#  8   GLASS TYPE   387 non-null    object
#  9   LITRES       432 non-null    int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 33.9+ KB

# %%
DF=DF.drop(["LITERS"],axis=1)

# %%
DF
# Out:
#      RATING  PRICESS              COOLING SYS  BRAND STAR  \
# 0       4.4  12990.0  Direct Cool Single Door           2
# 1       4.5  17890.0  Direct Cool Single Door           5
# 2       4.5  16650.0  Direct Cool Single Door           4
# 3       4.3  11990.0  Direct Cool Single Door           2
# 4       4.4  16650.0  Direct Cool Single Door           4
# ..      ...      ...                      ...         ...
# 427     4.2  20700.0  Direct Cool Single Door           3
# 428     4.3  15390.0  Direct Cool Single Door           3
# 429     4.4  16390.0  Direct Cool Single Door           3
# 430     3.8  16500.0  Direct Cool Single Door           3
# 431     4.5  17990.0  Direct Cool Single Door           4
#
#                   STABILIZER      Brand INVERTER          GLASS TYPE  LITRES
# 0    Built-in Stabilizer2021    SAMSUNG       NO  20%Toughened Glass     192
# 1    Built-in Stabilizer2020    SAMSUNG      Yes  55%Toughened Glass     198
# ...

# %% [markdown]
# # histogram ploting for only one numeric values

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid')

sns.histplot(data=DF,x='RATING',kde=True)
plt.show()

# %%
sns.set(style='whitegrid')

sns.histplot(data=DF,x='RATING',bins=20)
plt.show()

# %% [markdown]
# # Density chat for one numeric values

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")

 
# Make default density plot
sns.kdeplot(DF['BRAND STAR'])
plt.show()

# %% [markdown]
# # BOX PLOT FOR

# %%
# library & dataset
import seaborn as sns


sns.boxplot( x=DF["RATING"], y=DF["PRICESS"] )
# Out:
# <AxesSubplot:xlabel='RATING', ylabel='PRICESS'>

# %% [markdown]
# # A scatterplot displays the relationship between 2 numeric variables. For each data point, the value of its first variable is represented on the X axis, the second on the Y axis

# %%
# library & dataset
import seaborn as sns
import matplotlib.pyplot as plt

 
# use the function regplot to make a scatterplot
sns.regplot(x=DF["RATING"], y=DF["LITERS"])
 
# make a scatterplot without regression fit
#ax = sns.regplot(x=df["sepal_length"], y=df["sepal_width"], fit_reg=False)

plt.show()

# %%
# library and dataset
import seaborn as sns
import matplotlib.pyplot as plt

 
# change shape of marker
sns.regplot(x=DF["RATING"], y=DF["PRICESS"], marker="+", fit_reg=False)

plt.show()

# %% [raw]
# A boxplot gives a nice summary of one or several numeric variables. The line that divides the box into 2 parts represents the median of the data. The end of the box shows the upper and lower quartiles. The extreme lines show the highest and lowest value excluding outliers.

# %% [markdown]
# # BOX PLOT FOR THREE NUMERIC

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")


sns.boxplot(x=DF["RATING"], y=DF["PRICESS"], palette="Blues")
plt.show()

# %% [markdown]
# # one scatter and several numeric -- grouped scattert

# %%
# library & dataset
import seaborn as sns
import matplotlib.pyplot as plt
 
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="Brand", y="PRICESS", data=DF, fit_reg=False, hue='RATING', legend=False )
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
plt. figure(figsize=(10000,10000))

plt.show()

# %% [markdown]
# # one catgorical and one numeric

# %% [markdown]
# # bar plot FOR BRAND AND PRICEES

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='Brand', y='PRICESS', data=DF)
plt.show()

# %% [markdown]
# # BAR PLOT FOR  BRAND AND LITERS

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='Brand', y='LITERS', data=DF)
plt.show()

# %% [markdown]
# #  COUNT PLOT FOR ONE catogoric

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=DF['Brand'])
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='count'>

# %% [markdown]
# # histogram for brand as catogoric

# %%
plt.figure(figsize=(10,10))
sns.histplot(x=DF['Brand'])
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Count'>

# %% [markdown]
# #  LINE PLOT FOR ONE NUMERIC AND ONE CATOGORIC

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x=DF['Brand'], y=DF['PRICESS'])
plt.grid()

# %%
plt.figure(figsize=(20,5))

sns.lineplot(x=DF['Brand'], y=DF['RATING'])
plt.grid()

# %% [markdown]
# # PIE CHART
